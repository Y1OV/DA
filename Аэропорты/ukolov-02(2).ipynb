# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import awoc

# %%
airport_raw = pd.read_csv('https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat', header = None)

# %%
airport_raw.columns = ['Airport ID', 'Name', 'City', 'Country', 'IATA', 'ICAO', 'Latitude',
                       'Longitude', 'Altitude', 'Timezone', 'DST', 'time zone', 'Type', 'Source']

# %%
airport_raw.head()
# Out:
#    Airport ID                                         Name          City  \
# 0           1                               Goroka Airport        Goroka
# 1           2                               Madang Airport        Madang
# 2           3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3           4                               Nadzab Airport        Nadzab
# 4           5  Port Moresby Jacksons International Airport  Port Moresby
#
#             Country IATA  ICAO  Latitude   Longitude  Altitude Timezone DST  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282       10   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20       10   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388       10   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239       10   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146       10   U
#
#               time zone     Type       Source
# ...

# %%
rout_raw = pd.read_csv('https://raw.githubusercontent.com/jpatokal/openflights/master/data/routes.dat', header = None)

# %%
rout_raw.columns = ['Airline', 'Airline ID', 'Source airport', 'Source airport ID', 'Destination airport',
 'Destination airport ID', 'Codeshare', 'Stops', 'Equipment']

# %%
rout_raw.head()
# Out:
#   Airline Airline ID Source airport Source airport ID Destination airport  \
# 0      2B        410            AER              2965                 KZN
# 1      2B        410            ASF              2966                 KZN
# 2      2B        410            ASF              2966                 MRV
# 3      2B        410            CEK              2968                 KZN
# 4      2B        410            CEK              2968                 OVB
#
#   Destination airport ID Codeshare  Stops Equipment
# 0                   2990       NaN      0       CR2
# 1                   2990       NaN      0       CR2
# 2                   2962       NaN      0       CR2
# 3                   2990       NaN      0       CR2
# 4                   4078       NaN      0       CR2

# %% [markdown]
# # Задание 2

# %%
airport_raw[airport_raw['IATA'] == '\\N']
# Out:
#       Airport ID                               Name          City  Country  \
# 21            22     Winnipeg / St. Andrews Airport      Winnipeg   Canada
# 22            23  Halifax / CFB Shearwater Heliport       Halifax   Canada
# 43            44                  Princeton Airport     Princeton   Canada
# 103          104               Pitt Meadows Airport  Pitt Meadows   Canada
# 210          212                   Boufarik Airport      Boufarik  Algeria
# ...          ...                                ...           ...      ...
# 7692       14105                   Kubinka Air Base       Kubinka   Russia
# 7693       14106                Rogachyovo Air Base        Belaya   Russia
# 7694       14107              Ulan-Ude East Airport      Ulan Ude   Russia
# 7695       14108               Krechevitsy Air Base      Novgorod   Russia
# 7697       14110                 Melitopol Air Base     Melitopol  Ukraine
#
#      IATA  ICAO   Latitude   Longitude  Altitude Timezone DST  \
# ...

# %% [markdown]
# ### Самые главные, простые и неточные данные - это их отсутвие, в различных колонках (IATA, Timezone, DST, timezone и.т.д) пропущены данные - \N

# %%
rout_raw[rout_raw['Source airport'] == rout_raw['Destination airport']]
# Out:
#       Airline Airline ID Source airport Source airport ID Destination airport  \
# 33276      IL      10121            PKN              3910                 PKN
#
#       Destination airport ID Codeshare  Stops Equipment
# 33276                   3910       NaN      0       AT7

# %% [markdown]
# ### Также имеем проблему одного и тогоже кода IATA  в аэрапорте вылета и в аэропорте прилёта, следовательно самолёт вылетел из одного аэропорта и прилетел в тот же. Чисто технически такое возможно, самолёт мог вылететь и из-за плохих погодных условий вернулся обратно.

# %%
airport_raw[airport_raw['IATA'] == 'PNA']
# Out:
#       Airport ID              Name      City Country IATA  ICAO  Latitude  \
# 1201        1234  Pamplona Airport  Pamplona   Spain  PNA  LEPP     42.77
#
#       Longitude  Altitude Timezone DST      time zone     Type       Source
# 1201   -1.64633      1504        1   E  Europe/Madrid  airport  OurAirports

# %%
airport_raw[airport_raw['IATA'] == 'HLE']
# Out:
#       Airport ID                Name      City         Country IATA  ICAO  \
# 7400       13180  St. Helena Airport  Longwood  United Kingdom  HLE  FHSH
#
#        Latitude  Longitude  Altitude Timezone DST time zone     Type  \
# 7400 -15.957725  -5.645943      1017        0   U        \N  airport
#
#            Source
# 7400  OurAirports

# %% [markdown]
# ### Ещё бывют случаи, такие что указаны неверные координаты аэропорта, то есть город написан один, но по координатам он в другом месте, проще всего это увидеть при выполнении 3-го задания, когда мы будем визуализировать все аэропорты.
